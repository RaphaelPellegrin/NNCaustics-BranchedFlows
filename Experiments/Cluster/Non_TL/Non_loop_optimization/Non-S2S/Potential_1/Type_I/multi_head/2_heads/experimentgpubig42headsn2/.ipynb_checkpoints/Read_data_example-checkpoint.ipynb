# %% [markdown]
# This notebooks shows how to load the data form the cluster.

# %%
pwd
# Out:
# '/Users/pellegrinraphael/Desktop/Harvard/Year_2/ME_thesis/NNCaustics-BranchedFlows/Experiments/Cluster/Non_TL/Non_loop_optimization/Type_II/3_heads/experiment4'

# %%
cd /Users/pellegrinraphael/Desktop/Harvard/Year_2/ME_thesis/NNCaustics-BranchedFlows/Experiments/Cluster/Non_TL/Non_loop_optimization/Type_II
# Out:
# /Users/pellegrinraphael/Desktop/Harvard/Year_2/ME_thesis/NNCaustics-BranchedFlows/Experiments/Cluster/Non_TL/Non_loop_optimization/Type_II

# %%
ls
# Out:
# 3_heads/    5_heads/    Cluster.py  Notes

# %%
cd 3_heads
# Out:
# /Users/pellegrinraphael/Desktop/Harvard/Year_2/ME_thesis/NNCaustics-BranchedFlows/Experiments/Cluster/Non_TL/Non_loop_optimization/Type_II/3_heads

# %%
cd experiment5
# Out:
# /Users/pellegrinraphael/Desktop/Harvard/Year_2/ME_thesis/NNCaustics-BranchedFlows/Experiments/Cluster/Non_TL/Non_loop_optimization/Type_II/3_heads/experiment5

# %%
ls
# Out:
# Cluster_3.py
# GPU_3.sh
# Head_0Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000TrajectoriesNumerical_px.p
# Head_0Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000TrajectoriesNumerical_py.p
# Head_0Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000TrajectoriesNumerical_x.p
# Head_0Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000TrajectoriesNumerical_y.p
# Head_0Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000Trajectory_NN_px.p
# Head_0Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000Trajectory_NN_py.p
# Head_0Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000Trajectory_NN_x.p
# Head_0Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000Trajectory_NN_y.p
# Head_1Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000TrajectoriesNumerical_px.p
# Head_1Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000TrajectoriesNumerical_py.p
# Head_1Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000TrajectoriesNumerical_x.p
# Head_1Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000TrajectoriesNumerical_y.p
# Head_1Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000Trajectory_NN_px.p
# Head_1Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000Trajectory_NN_py.p
# Head_1Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000Trajectory_NN_x.p
# Head_1Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000Trajectory_NN_y.p
# Head_2Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000TrajectoriesNumerical_px.p
# Head_2Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000TrajectoriesNumerical_py.p
# Head_2Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000TrajectoriesNumerical_x.p
# Head_2Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000TrajectoriesNumerical_y.p
# Head_2Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000Trajectory_NN_px.p
# Head_2Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000Trajectory_NN_py.p
# Head_2Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000Trajectory_NN_x.p
# Head_2Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000Trajectory_NN_y.p
# Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000Grid-x1.p
# Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000Grid-y1.p
# Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000Grid.p
# Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000Grid_potential_values.p
# Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000Initial_conditions.p
# Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000Means.p
# Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000Network_state.p
# Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000d_comparaison.p
# Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000loss.p
# Initial_x_0final_t_10alpha_1width_64width_heads_32energyconservation_True_normclipping_True_epochs_60000grid_size_20000losses_part.p
# logs_57212613.err
# logs_57212613.out
# models

# %%
import numpy as np
import copy
import pickle
import string
import json

import matplotlib.pyplot as plt

# %%
initial_x=0
final_t=10
alpha_=1
width_=64
width_heads=32
epochs_=60000
grid_size=20000
energy_conservation=True
norm_clipping=True
number_of_heads=3

# %%
import torch

# %%
filename = 'Initial_x_'+str(initial_x)+'final_t_'+str(final_t)+\
  'alpha_'+ str(alpha_)+'width_'+str(width_)+'width_heads_'+str(width_heads)+\
  'energyconservation_'+str(energy_conservation)+\
  '_normclipping_'+str(norm_clipping)+'_'\
  'epochs_'+str(epochs_)+'grid_size_'+str(grid_size)+'Network_state'+'.p'

#networkstate=pickle.load(open(filename,"rb"))

# %%
#networkstate;

# %%
filename = 'Initial_x_'+str(initial_x)+'final_t_'+str(final_t)+\
  'alpha_'+ str(alpha_)+'width_'+str(width_)+'width_heads_'+str(width_heads)+\
  'energyconservation_'+str(energy_conservation)+\
  '_normclipping_'+str(norm_clipping)+'_'\
  'epochs_'+str(epochs_)+'grid_size_'+str(grid_size)+'loss'+'.p'

loss=pickle.load(open(filename,"rb"))

# %%
f,ax=plt.subplots(1,1,figsize=(16,8))
ax.grid()
ax.set_title("Loss")
ax.set_xlabel("Number of epochs")
ax.set_ylabel("Loss")
ax.plot(range(len(loss)),loss)
ax.set_yscale('log')
if number_of_heads>1:
    filename_p = 'Initial_x_'+str(initial_x)+'final_t_'+str(final_t)+\
      'alpha_'+ str(alpha_)+'width_'+str(width_)+'width_heads_'+str(width_heads)+\
      'energyconservation_'+str(energy_conservation)+\
      '_normclipping_'+str(norm_clipping)+'_'\
      'epochs_'+str(epochs_)+'grid_size_'+str(grid_size)+'losses_part'+'.p'
    loss_p=pickle.load(open(filename_p,"rb"))
    for j in range(number_of_heads):
        ax.plot(range(len(loss_p[j])),loss_p[j], alpha=0.2)

# %%
Trajectories_NN_x=dict()
Trajectories_NN_y=dict()
Trajectories_NN_px=dict()
Trajectories_NN_py=dict()

f,ax=plt.subplots(1,1,figsize=(16,8))

for m in range(number_of_heads):
    filename = 'Head_'+str(m)+'Initial_x_'+str(initial_x)+'final_t_'+\
        str(final_t)+'alpha_'+ str(alpha_)+'width_'+str(width_)+'width_heads_'+str(width_heads)+\
        'energyconservation_'+str(energy_conservation)+\
        '_normclipping_'+str(norm_clipping)+'_'\
        'epochs_'+str(epochs_)+'grid_size_'+str(grid_size)+\
        'Trajectory_NN_x'+'.p'
    


    NNx=pickle.load(open(filename,"rb"))
    Trajectories_NN_x[m]=NNx
    

    filename = 'Head_'+str(m)+'Initial_x_'+str(initial_x)+'final_t_'+\
        str(final_t)+'alpha_'+ str(alpha_)+'width_'+str(width_)+'width_heads_'+str(width_heads)+\
        'energyconservation_'+str(energy_conservation)+\
        '_normclipping_'+str(norm_clipping)+'_'\
        'epochs_'+str(epochs_)+'grid_size_'+str(grid_size)+\
        'Trajectory_NN_y'+'.p'

    NNy=pickle.load(open(filename,"rb"))
    Trajectories_NN_y[m]=NNy
    
    ax.plot(NNx,NNy, ls=':', label="NN solution of SDE stoc for {} head".format(m+1))

    filename = 'Head_'+str(m)+'Initial_x_'+str(initial_x)+'final_t_'+\
        str(final_t)+'alpha_'+ str(alpha_)+'width_'+str(width_)+'width_heads_'+str(width_heads)+\
        'energyconservation_'+str(energy_conservation)+\
        '_normclipping_'+str(norm_clipping)+'_'\
        'epochs_'+str(epochs_)+'grid_size_'+str(grid_size)+\
        'Trajectory_NN_px'+'.p'

    NNpx=pickle.load(open(filename,"rb"))
    Trajectories_NN_px[m]=NNpx

    filename = 'Head_'+str(m)+'Initial_x_'+str(initial_x)+'final_t_'+\
        str(final_t)+'alpha_'+ str(alpha_)+'width_'+str(width_)+'width_heads_'+str(width_heads)+\
        'energyconservation_'+str(energy_conservation)+\
        '_normclipping_'+str(norm_clipping)+'_'\
        'epochs_'+str(epochs_)+'grid_size_'+str(grid_size)+'Trajectory_NN_py'+'.p'

    NNpy=pickle.load(open(filename,"rb"))
    Trajectories_NN_py[m]=NNpy
    
# Make a grid, set the title and the labels
ax.grid()
ax.set_title("Rays - NN solution")
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
# Out:
# Text(0, 0.5, '$y$')

# %%
filename = 'Initial_x_'+str(initial_x)+'final_t_'+str(final_t)+'alpha_'+ str(alpha_)+'width_'+str(width_)+\
  'width_heads_'+str(width_heads)+\
  'energyconservation_'+str(energy_conservation)+\
  '_normclipping_'+str(norm_clipping)+'_'\
  'epochs_'+str(epochs_)+'grid_size_'+str(grid_size)+'Initial_conditions'+'.p'
Initial_conditions=pickle.load(open(filename,"rb"))

# %%
Initial_conditions;

# %%
for i in Initial_conditions:
    print("The initial condition is {}".format(Initial_conditions[i]))
# Out:
# The initial condition is 46.32
# The initial condition is 44.95
# The initial condition is 6.79

# %%
filename = 'Initial_x_'+str(initial_x)+'final_t_'+str(final_t)+'alpha_'+ str(alpha_)+'width_'+str(width_)+\
  'width_heads_'+str(width_heads)+\
  'energyconservation_'+str(energy_conservation)+\
  '_normclipping_'+str(norm_clipping)+'_'\
  'epochs_'+str(epochs_)+'grid_size_'+str(grid_size)+'d_comparaison'+'.p'
#Network=pickle.load(open(filename,"rb"))

# %%
#Network;

# %%
f,ax=plt.subplots(1,1,figsize=(16,8))

for m in range(number_of_heads):    
    filename = 'Head_'+str(m)+'Initial_x_'+str(initial_x)+'final_t_'+str(final_t)+'alpha_'+ str(alpha_)+'width_'+str(width_)+\
          'width_heads_'+str(width_heads)+\
          'energyconservation_'+str(energy_conservation)+\
          '_normclipping_'+str(norm_clipping)+'_'\
          'epochs_'+str(epochs_)+'grid_size_'+str(grid_size)+'TrajectoriesNumerical_x'+'.p'

    Numericalx=pickle.load(open(filename,"rb"))

    filename = 'Head_'+str(m)+'Initial_x_'+str(initial_x)+'final_t_'+str(final_t)+'alpha_'+ str(alpha_)+'width_'+str(width_)+\
          'width_heads_'+str(width_heads)+\
          'energyconservation_'+str(energy_conservation)+\
          '_normclipping_'+str(norm_clipping)+'_'\
          'epochs_'+str(epochs_)+'grid_size_'+str(grid_size)+'TrajectoriesNumerical_y'+'.p'

    Numericaly=pickle.load(open(filename,"rb"))
    
    ax.plot(Numericalx,Numericaly, ls=':', label="NN solution of SDE stoc for {} head".format(m+1))

    filename = 'Head_'+str(m)+'Initial_x_'+str(initial_x)+'final_t_'+str(final_t)+'alpha_'+ str(alpha_)+'width_'+str(width_)+\
          'width_heads_'+str(width_heads)+\
          'energyconservation_'+str(energy_conservation)+\
          '_normclipping_'+str(norm_clipping)+'_'\
          'epochs_'+str(epochs_)+'grid_size_'+str(grid_size)+'TrajectoriesNumerical_px'+'.p'

    Numericalpx=pickle.load(open(filename,"rb"))

    filename = 'Head_'+str(m)+'Initial_x_'+str(initial_x)+'final_t_'+str(final_t)+'alpha_'+ str(alpha_)+'width_'+str(width_)+\
          'width_heads_'+str(width_heads)+\
          'energyconservation_'+str(energy_conservation)+\
          '_normclipping_'+str(norm_clipping)+'_'\
          'epochs_'+str(epochs_)+'grid_size_'+str(grid_size)+'TrajectoriesNumerical_py'+'.p'

    Numericalpy=pickle.load(open(filename,"rb"))
    
# Make a grid, set the title and the labels
ax.grid()
ax.set_title("Rays - Numerical solutions")
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
# Out:
# Text(0, 0.5, '$y$')

# %%
Numericalx;

# %%
Numericaly;

# %%
filename = 'Initial_x_'+str(initial_x)+'final_t_'+str(final_t)+'alpha_'+ str(alpha_)+'width_'+str(width_)+\
  'width_heads_'+str(width_heads)+\
  'energyconservation_'+str(energy_conservation)+\
  '_normclipping_'+str(norm_clipping)+'_'\
  'epochs_'+str(epochs_)+'grid_size_'+str(grid_size)+'Means'+'.p'
Means=pickle.load(open(filename,"rb"))

# %%
Means;

# %%
filename = 'Initial_x_'+str(initial_x)+'final_t_'+str(final_t)+'alpha_'+ str(alpha_)+'width_'+str(width_)+\
  'width_heads_'+str(width_heads)+\
  'energyconservation_'+str(energy_conservation)+\
  '_normclipping_'+str(norm_clipping)+'_'\
  'epochs_'+str(epochs_)+'grid_size_'+str(grid_size)+'Grid'+'.p'
Grid=pickle.load(open(filename,"rb"))

# %%
Grid;

# %%
filename = 'Initial_x_'+str(initial_x)+'final_t_'+str(final_t)+'alpha_'+ str(alpha_)+'width_'+str(width_)+\
  'width_heads_'+str(width_heads)+\
  'energyconservation_'+str(energy_conservation)+\
  '_normclipping_'+str(norm_clipping)+'_'\
  'epochs_'+str(epochs_)+'grid_size_'+str(grid_size)+'Grid_potential_values'+'.p'
Grid_potential_value=pickle.load(open(filename,"rb"))

# %%
filename = 'Initial_x_'+str(initial_x)+'final_t_'+str(final_t)+'alpha_'+ str(alpha_)+'width_'+str(width_)+\
  'width_heads_'+str(width_heads)+\
  'energyconservation_'+str(energy_conservation)+\
  '_normclipping_'+str(norm_clipping)+'_'\
  'epochs_'+str(epochs_)+'grid_size_'+str(grid_size)+'Grid-x1'+'.p'
Gridx1=pickle.load(open(filename,"rb"))

# %%
filename = 'Initial_x_'+str(initial_x)+'final_t_'+str(final_t)+'alpha_'+ str(alpha_)+'width_'+str(width_)+\
  'width_heads_'+str(width_heads)+\
  'energyconservation_'+str(energy_conservation)+\
  '_normclipping_'+str(norm_clipping)+'_'\
  'epochs_'+str(epochs_)+'grid_size_'+str(grid_size)+'Grid-y1'+'.p'
Gridy1=pickle.load(open(filename,"rb"))

# %%
Grid_potential_value
# Out:
# array([[-2.32625380e-10, -2.61941327e-10, -2.94796737e-10, ...,
#         -1.04277158e-01, -1.04466499e-01, -1.04655093e-01],
#        [-3.36837442e-10, -3.79287433e-10, -4.26862721e-10, ...,
#         -1.15460346e-01, -1.15674344e-01, -1.15887753e-01],
#        [-4.83189353e-10, -5.44085072e-10, -6.12333357e-10, ...,
#         -1.26728054e-01, -1.26969296e-01, -1.27210177e-01],
#        ...,
#        [-4.50211925e-09, -4.98794774e-09, -5.52624981e-09, ...,
#         -6.71771131e-02, -6.71635972e-02, -6.71209507e-02],
#        [-3.18336453e-09, -3.53871163e-09, -3.93391380e-09, ...,
#         -7.40078930e-02, -7.39301789e-02, -7.38189197e-02],
#        [-2.27639232e-09, -2.53944872e-09, -2.83308795e-09, ...,
#         -8.15775498e-02, -8.14404185e-02, -8.12651684e-02]])

# %%
f, ax =plt.subplots(1,1, figsize=(20,10))
ax.contourf(Gridx1,Gridy1,Grid_potential_value,levels=20);
ax.grid()
ax.set_title("Potential")
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
# Out:
# Text(0, 0.5, '$y$')

# %%
f, ax =plt.subplots(1,1, figsize=(20,10))
ax.contourf(Gridx1,Gridy1,Grid_potential_value,levels=20);
for m in range(number_of_heads):    
    filename = 'Head_'+str(m)+'Initial_x_'+str(initial_x)+'final_t_'+str(final_t)+'alpha_'+ str(alpha_)+'width_'+str(width_)+\
          'width_heads_'+str(width_heads)+\
          'energyconservation_'+str(energy_conservation)+\
          '_normclipping_'+str(norm_clipping)+'_'\
          'epochs_'+str(epochs_)+'grid_size_'+str(grid_size)+'TrajectoriesNumerical_x'+'.p'

    Numericalx=pickle.load(open(filename,"rb"))

    filename = 'Head_'+str(m)+'Initial_x_'+str(initial_x)+'final_t_'+str(final_t)+'alpha_'+ str(alpha_)+'width_'+str(width_)+\
          'width_heads_'+str(width_heads)+\
          'energyconservation_'+str(energy_conservation)+\
          '_normclipping_'+str(norm_clipping)+'_'\
          'epochs_'+str(epochs_)+'grid_size_'+str(grid_size)+'TrajectoriesNumerical_y'+'.p'

    Numericaly=pickle.load(open(filename,"rb"))
    
    ax.plot(Numericalx,Numericaly, ls=(0,(5,5)), label="NN solution of SDE stoc for {} head".format(m+1))
    
for m in range(number_of_heads):
    filename = 'Head_'+str(m)+'Initial_x_'+str(initial_x)+'final_t_'+\
        str(final_t)+'alpha_'+ str(alpha_)+'width_'+str(width_)+'width_heads_'+str(width_heads)+\
        'energyconservation_'+str(energy_conservation)+\
        '_normclipping_'+str(norm_clipping)+'_'\
        'epochs_'+str(epochs_)+'grid_size_'+str(grid_size)+\
        'Trajectory_NN_x'+'.p'
    

    NNx=pickle.load(open(filename,"rb"))
    Trajectories_NN_x[m]=NNx
    

    filename = 'Head_'+str(m)+'Initial_x_'+str(initial_x)+'final_t_'+\
        str(final_t)+'alpha_'+ str(alpha_)+'width_'+str(width_)+'width_heads_'+str(width_heads)+\
        'energyconservation_'+str(energy_conservation)+\
        '_normclipping_'+str(norm_clipping)+'_'\
        'epochs_'+str(epochs_)+'grid_size_'+str(grid_size)+\
        'Trajectory_NN_y'+'.p'

    NNy=pickle.load(open(filename,"rb"))
    Trajectories_NN_y[m]=NNy
    
    ax.plot(NNx,NNy, ls=':', label="NN solution of SDE stoc for {} head".format(m+1))
    
ax.grid()
ax.set_title("Potential with the rays")
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
# Out:
# Text(0, 0.5, '$y$')

# %% [markdown]
# Could also recreate the potential from the means.
